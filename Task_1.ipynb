# %%
import pandas as pd 
import matplot as plt 
import numpy as nu

# %%
data_frame = pd.read_csv (r"D:\AI Diplome\Day 1\Ice Cream Ratings.csv")
data_frame = data_frame.set_index ('Date')
data_frame
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
data_frame.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data_frame.plot(kind = 'line', title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
data_frame.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
data_frame.plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_frame.plot.pie(y='Flavor Rating',figsize=(10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
